# %% [markdown]
# # Exercise 01: ReLU vs Linear Visualization
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shang-vikas/series1-coding-exercises/blob/main/exercises/blog-02/exercise-01.ipynb)

# %% [markdown]
# ## Setup

# %%
# Install required packages using the kernel's Python interpreter
import sys
import subprocess
import importlib

def install_if_missing(package, import_name=None):
    """Install package if it's not already installed."""
    if import_name is None:
        import_name = package

    try:
        importlib.import_module(import_name)
        print(f"✓ {package} is already installed")
    except ImportError:
        print(f"Installing {package}....")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"✓ {package} installed successfully")

# Install required packages
install_if_missing("numpy")
install_if_missing("matplotlib")
# Out:
# ✓ numpy is already installed
# ✓ matplotlib is already installed

# %% [markdown]
# ## 💻 Micro Exercise

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
relu = np.maximum(0, x)

plt.plot(x, x, label="Linear")
plt.plot(x, relu, label="ReLU")
plt.legend()
plt.show()

# %% [markdown]
# ## Reflection
#
# Stack linear layers → still linear.
#
# Add ReLU → shape changes.
#
# No deeper math needed.
